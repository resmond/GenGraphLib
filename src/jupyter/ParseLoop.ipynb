# %%
test_1 = "This ia a test of text[ 15462.45 ] of thing:foo = 25"
test_2 = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghihklmnopqrstuvwxyz"
test_buffer: bytes = test_2.encode( 'latin1' )



# i: int = -1
# for c in test_buffer:
#     i += 1
#     byte1 = c & 0x88
#     print(f'{test_2[i]}  {chr(c)} {int(c):3}   {c:08b}  {byte1:08b}')

for n in range(0,126):
    bitsplit = f'{n:08b}'
    left = bitsplit[:4]
    right = bitsplit[4:]



    #print(f'{n} = {chr(n)} - {n:08b}  {left} {right}')
    print(f'tab = ')
# Out:
# 0 =  - 00000000  0000 0000
# 1 =  - 00000001  0000 0001
# 2 =  - 00000010  0000 0010
# 3 =  - 00000011  0000 0011
# 4 =  - 00000100  0000 0100
# 5 =  - 00000101  0000 0101
# 6 =  - 00000110  0000 0110
# 7 =  - 00000111  0000 0111
# 8 = - 00001000  0000 1000
# 9 = 	 - 00001001  0000 1001
# 10 =
#  - 00001010  0000 1010
# 11 =  - 00001011  0000 1011
# 12 =  - 00001100  0000 1100
#  - 00001101  0000 1101
# 14 =  - 00001110  0000 1110
# 15 =  - 00001111  0000 1111
# 16 =  - 00010000  0001 0000
# 17 =  - 00010001  0001 0001
# 18 =  - 00010010  0001 0010
# 19 =  - 00010011  0001 0011
# 20 =  - 00010100  0001 0100
# 21 =  - 00010101  0001 0101
# 22 =  - 00010110  0001 0110
# 23 =  - 00010111  0001 0111
# 24 =  - 00011000  0001 1000
# 25 =  - 00011001  0001 1001
# 26 =  - 00011010  0001 1010
# 27 =  - 00011011  0001 1011
# 28 =  - 00011100  0001 1100
# 29 =  - 00011101  0001 1101
# 30 =  - 00011110  0001 1110
# 31 =  - 00011111  0001 1111
# 32 =   - 00100000  0010 0000
# ...
